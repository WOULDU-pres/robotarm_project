# %% [markdown]
# <center><img src="../../logo.png" alt="Header" style="width: 800px;"/></center>

# %% [markdown]
# @Copyright (C): 2010-2022, Shenzhen Yahboom Tech
# @Author: Liusen
# @Date: 2020-02-19 17:09:00
# @LastEditors: Liusen
# @LastEditTime: 2020-02-19 17:09:00

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('Road_test.jpg', 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-3vel1tv3 because the default path (/home/jetson/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# # plot drawing histogram

# %%
plt.hist(img.ravel(), 256)   #ravel() Two-dimensional to one-dimensional 256 gray level grouping	
plt.show()

# %%
# plot draws the histogram value returned by opencv

# %%
histb = cv2.calcHist([img], [0], None, [256], [0, 255])
plt.plot(histb, color='b')
plt.show()
