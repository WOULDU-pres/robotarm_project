# %% [markdown]
# <center><img src="../../logo.png" alt="Header" style="width: 800px;"/></center>

# %% [markdown]
# @Copyright (C): 2010-2022, Shenzhen Yahboom Tech
# @Author: Liusen
# @Date: 2020-02-19 15:29:00
# @LastEditors: Liusen
# @LastEditTime: 2020-02-19 15:29:00

# %% [markdown]
# # Drawing text

# %%
import cv2 
import numpy as np

img = cv2.imread('yahboom.jpg',1)
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.rectangle(img,(200,100),(500,400),(0,255,0),3)
# 1 dst 2need add text 3coordinate 4 5 size of font 6 color 7 thickness 8 line type
cv2.putText(img,'Yahboom',(250,50),font,1,(200,200,0),2,cv2.LINE_AA)
# cv2.imshow('src',img)
# cv2.waitKey(0)
# Out:
# array([[[60, 51, 38],
#         [66, 48, 37],
#         [79, 54, 44],
#         ...,
#         [15, 13, 13],
#         [15, 13, 13],
#         [21, 19, 19]],
#
#        [[55, 43, 31],
#         [61, 41, 30],
#         [75, 48, 38],
#         ...,
#         [20, 18, 18],
#         [18, 16, 16],
#         [21, 19, 19]],
#
#        [[54, 38, 26],
#         [62, 37, 27],
#         [77, 46, 37],
#         ...,
#         [18, 16, 16],
#         [12, 10, 10],
#         [10,  8,  8]],
#
#        ...,
#
#        [[28, 23, 22],
#         [28, 23, 22],
#         [28, 23, 22],
#         ...,
#         [31, 26, 25],
#         [28, 23, 22],
#         [27, 22, 21]],
#
#        [[28, 23, 22],
#         [28, 23, 22],
#         [28, 23, 22],
#         ...,
#         [30, 25, 24],
#         [32, 27, 26],
#         [28, 23, 22]],
#
#        [[29, 24, 23],
#         [29, 24, 23],
#         [29, 24, 23],
#         ...,
#         [27, 22, 21],
#         [32, 27, 26],
#         [27, 22, 21]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

dst = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(dst)
plt.show()
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-pc0c7fo4 because the default path (/home/jetson/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# # Drawing picture

# %%
import cv2 
img = cv2.imread('yahboom.jpg',1)
height = int(img.shape[0]*0.2)
width = int(img.shape[1]*0.2)
imgResize = cv2.resize(img,(width,height))
for i in range(0,height):
    for j in range(0,width):
        img[i+200,j+350] = imgResize[i,j]
# cv2.imshow('src',img)
# cv2.waitKey(0)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
